# %%
import sys
import numpy as np
from scipy import ndimage
from scipy.misc import imsave

# %%
import matplotlib.pyplot as plt
im = ndimage.imread('20.jpg', mode='L')
N = 20
plt.figure(figsize=(14,7))
for x in xrange(N):
    cropped = im[x * im.shape[0]/N: (x+1) * im.shape[0]/N, :]
    cropped_and_filtered = ndimage.filters.maximum_filter(cropped, size=(25,1))
    
    cropped_and_filtered= ndimage.zoom(cropped_and_filtered, 0.1)
    x3
    plt.imshow(cropped_and_filtered)
    plt.subplot(N, 2, 2*x+2)
    plt.imshow(cropped)
